# %% [markdown]
# # Week 2 Homework: Draft of Data Preprocessing of Machine Learning Solution Project Dataset
#
#
# ---
#
#
# Data preprocessing ensures that the data used to develop machine learning solutions is clean, consistent, and relevant. For the next two weeks, you will preprocess the FinMark Corporation datasets. The main objective of this activity is to exercise your familiarity and skills in data preprocessing using Python.
#
# <br>
#
# To carry out this activity, follow the instructions below:
#
# 1. Access the company website here. Review the problem statement and download the provided datasets.
#
# 2. Load the downloaded datasets in Jupyter Notebooks and preprocess them using Pandas:
#
#     a. Check for duplicate rows and remove them.
#
#     b. Identify columns with missing values and decide how to handle them.
#
#     c. Ensure columns have the appropriate data types.
#
# 3. Once completed, save the preprocessed datasets and prepare to discuss the output with your team.

# %% [markdown]
# To access files stored in Google Drive from Google Colab, it's necessary to connect Google Drive to the Colab environment. This allows direct access to files stored in Drive. Follow these steps to mount Google Drive.

# %%
# Import the module to interact with Google Drive in Colab
from google.colab import drive

# Mount Google Drive to access files stored in your drive from Colab
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# To work with data from three CSV files in Python using pandas, first, import the pandas library. Then, load each CSV file into separate DataFrame variables df1, df2, and df3 by specifying the file paths.

# %%
# Import the pandas library
import pandas as pd

# Reading the CSV file into Pandas DataFrame
#Customer Segments
df1 = pd.read_csv('/content/drive/MyDrive/3rd year 2024-25/MO-IT125 - Math for Machine Learning: Linear Algebra/FinMark csv/customer_demographics_contaminated.csv')
#Customer Transactions
df2 = pd.read_csv('/content/drive/MyDrive/3rd year 2024-25/MO-IT125 - Math for Machine Learning: Linear Algebra/FinMark csv/customer_transactions_contaminated.csv')
#Social Media Interactions
df3 = pd.read_csv('/content/drive/MyDrive/3rd year 2024-25/MO-IT125 - Math for Machine Learning: Linear Algebra/FinMark csv/social_media_interactions_contaminated.csv')

# %% [markdown]
# After loading data into pandas DataFrames (df1, df2, df3), it's helpful to use the `info()` function. This function provides an overview of the structure of each dataset, including:
#
# The total number of entries (rows).
# The column names and their data types (e.g., integers, floats, strings).
# The number of non-null values in each column.
# Using `info()` helps in understanding the dataset at a glance, identifying missing values, and ensuring that the data types are as expected for further analysis.

# %%
# Summary of the DataFrame, including column names, non-null counts, data types, and memory usage
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   3200 non-null   object
#  1   Age          2909 non-null   object
#  2   Gender       3200 non-null   object
#  3   Location     3200 non-null   object
#  4   IncomeLevel  2897 non-null   object
#  5   SignupDate   3200 non-null   object
# dtypes: object(6)
# memory usage: 150.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3200 non-null   object
#  1   TransactionID    3200 non-null   object
#  2   TransactionDate  3200 non-null   object
#  3   Amount           2896 non-null   object
#  4   ProductCategory  2901 non-null   object
#  5   PaymentMethod    3200 non-null   object
# dtypes: object(6)
# memory usage: 150.1+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3200 non-null   object
#  1   InteractionID    3200 non-null   object
#  2   InteractionDate  3200 non-null   object
#  3   Platform         2889 non-null   object
#  4   InteractionType  3200 non-null   object
#  5   Sentiment        2871 non-null   object
# dtypes: object(6)
# memory usage: 150.1+ KB

# %% [markdown]
# The `describe()` function provides a summary of the statistical properties of the numerical columns in a dataset. This includes:
#
# * Count: The number of non-null entries in each column.
# * Mean: The average value.
# * Standard deviation (std): A measure of how spread out the values are.
# * Minimum (min) and Maximum (max) values.
# * Percentiles (25%, 50%, 75%): These help to understand the distribution of the data.
#
# Using `describe()` gives a quick overview of the central tendency, dispersion, and distribution of the numerical data, which is useful for understanding its characteristics before performing further analysis.

# %%
# Generate summary statistics for numeric columns in df, including count, mean, standard deviation, min, max, and percentiles (25%, 50%, 75%)
df1.describe()
# Out:
#                                   CustomerID   Age  Gender      Location  \
# count                                   3200  2909    3200          3200
# unique                                  3000    58       2          2696
# top     1a5115af-2fa7-4198-b838-be2cdeccb768  26.0  Female  Port Michael
# freq                                       2    72    1610             6
#
#        IncomeLevel  SignupDate
# count         2897        3200
# unique           3        1544
# top           High  2024-06-08
# freq          1004           9

# %%
df2.describe()
# Out:
#                                   CustomerID  \
# count                                   3200
# unique                                  1871
# top     49f06ea9-4ae5-4ce5-98ce-d2c2f6f15cbd
# freq                                       7
#
#                                TransactionID TransactionDate Amount  \
# count                                   3200            3200   2896
# unique                                  3000             808   2603
# top     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-01-06   -100
# freq                                       2              13     39
#
#        ProductCategory PaymentMethod
# count             2901          3200
# unique               5             4
# top           Clothing    Debit Card
# freq               598           809

# %%
df3.describe()
# Out:
#                                   CustomerID  \
# count                                   3200
# unique                                  1893
# top     fd35b6b4-ad1c-49cc-9c34-8c2d696f38e2
# freq                                       6
#
#                                InteractionID InteractionDate   Platform  \
# count                                   3200            3200       2889
# unique                                  3000             450          3
# top     e77a8713-fdc7-4f71-85f8-9cd88cca0c42      2023-07-02  Instagram
# freq                                       2              17        976
#
#        InteractionType Sentiment
# count             3200      2871
# unique               3         5
# top            Comment  Positive
# freq              1079       962

# %% [markdown]
# After loading the datasets, it’s important to check for duplicate rows, as these can lead to inaccurate analysis.
#
# This code loops through each DataFrame (`df1`, `df2`, and `df3`) and counts the number of duplicate rows using the `duplicated()` function. The result shows how many duplicate rows exist in each dataset, which can then be addressed if necessary.

# %%
# List of DataFrames
dataframes = [df1, df2, df3]

# Loop through each DataFrame to check for duplicates
for i, df in enumerate(dataframes, 1):
  num_duplicates = df.duplicated().sum()
  print(f"Number of duplicates in DataFrame {i}: {num_duplicates}")
# Out:
# Number of duplicates in DataFrame 1: 177
# Number of duplicates in DataFrame 2: 185
# Number of duplicates in DataFrame 3: 180

# %% [markdown]
# Instead of just counting the duplicates, this code prints the actual duplicate rows for further inspection.

# %%
# List of DataFrames
dataframes = [df1, df2, df3]

#Loop to check for duplicates
for df in dataframes:
  print(df[df.duplicated()])
# Out:
#                                 CustomerID   Age  Gender             Location  \
# 3000  89ae8d7c-cbcd-4117-8a06-d7ddc5fa9132  45.0  Female          Port Joseph
#
#       ProductCategory  PaymentMethod
# 3000    Home & Garden    Credit Card
# 3001    Home & Garden     Debit Card
# 3002      Electronics  Bank Transfer
# 3003  Health & Beauty    Credit Card
# 3004       Automotive  Bank Transfer
# ...               ...            ...
# 3195    Home & Garden  Bank Transfer
# 3196  Health & Beauty    Credit Card
# 3197    Home & Garden         PayPal
# 3198  Health & Beauty     Debit Card
# 3199      Electronics     Debit Card
#
# [185 rows x 6 columns]
#                                 CustomerID  \
# 3000  e7eb8a7a-5c2b-4b0d-9783-eaef25a5cd27
# 3001  56f11a95-76f1-4a97-b38f-db1dc95da1ed
# 3002  b01cf495-5ea5-4cb7-acd3-b2c1e6983959
# 3003  56a5cf77-1afc-4911-8259-9293710ca596
# 3004  174cbf14-d8c9-410d-a0d5-69c86c945f17
# ...                                    ...
# 3195  8d8fe8bd-2009-4a15-be37-83dba3cef447
# 3196  1756838b-8368-4852-b4a5-32a23643a3dd
# 3197  eb8bb3ce-e182-4a9c-8084-c55c738815e1
# 3198  a5d08a95-9dba-4e3d-b997-1cfdde6a89ef
# 3199  f8146100-569d-4cda-9d64-88c6ad98de5f
#
#                              InteractionID InteractionDate   Platform  \
# 3000  3b56fb3f-3311-4443-bd3d-03d1683d2500      2023-11-17   Facebook
# 3001  193c2897-e674-46da-a389-c68e45b6a68b      2024-01-13   Facebook
# 3002  b1bf47d0-5c42-4c8e-8108-6d8b36b38bde      2024-06-29  Instagram
# 3003  da6d86ee-bbdc-4e47-8e9a-e9b36715bd9e      2023-09-08   Facebook
# 3004  227619fa-5ba5-42aa-b257-9157cf9ccbee      2024-03-19    Twitter
# ...                                    ...             ...        ...
# 3195  2212803c-4a00-4263-bae5-aaaff6d6bdb1      2023-08-30  Instagram
# 3196  2f50ca57-f930-4d3e-ae08-9f3b26c7f148      2024-06-16   Facebook
# 3197  ee2c3d14-248c-48b0-aa80-4ea97e449bf8      2023-12-22  Instagram
# 3198  e77a8713-fdc7-4f71-85f8-9cd88cca0c42      2023-11-01    Twitter
# 3199  454a0b90-d1bb-437d-ad50-ef01821fbf0a      2024-06-20  Instagram
#
#      InteractionType Sentiment
# 3000         Comment  Positive
# 3001         Comment  Negative
# 3002         Comment   Neutral
# 3003         Comment   Neutral
# 3004           Share  Positive
# ...              ...       ...
# 3195            Like   Neutral
# 3196            Like   Neutral
# 3197         Comment  Negative
# 3198           Share  Positive
# 3199            Like   Neutral
#
# [180 rows x 6 columns]

# %% [markdown]
# The `drop_duplicates()` function removes any duplicate rows from each DataFrame. The `inplace=True` argument ensures that the changes are applied directly to the DataFrame.
#
# Once duplicates are removed, the code checks each DataFrame again for any remaining duplicates using the `duplicated()` function. If duplicates are found, they are printed for further review; otherwise, a message is displayed confirming that no duplicates remain.
#
# This two-step process ensures that the data is cleaned of duplicates.

# %%
# List of DataFrames
dataframes = [df1, df2, df3]

# Loop to remove duplicates from each DataFrame
for df in dataframes:
  df.drop_duplicates(inplace=True)

# Loop to check for duplicates in each DataFrame and print them if found
for df in dataframes:
  duplicates = df[df.duplicated()]
  if not duplicates.empty:
    print(f"Duplicates found:\n{duplicates}")
  else:
    print("No duplicates found.")
# Out:
# No duplicates found.
# No duplicates found.
# No duplicates found.

# %% [markdown]
# This code loops through each DataFrame (`df1`, `df2`, `df3`), using the `isnull().sum()` function to calculate the number of missing values in each column. Only columns with missing values are displayed, along with the total count of missing entries for easier identification.

# %%
# List of DataFrames
dataframes = [df1, df2, df3]

# Loop through each DataFrame to check for missing values
for i, df in enumerate(dataframes, 1):
    print(f"Missing Values in DataFrame {i}:")
    # Calculate the sum of missing values for each column
    missing_values = df.isnull().sum()

    # Print columns with missing values
    print(missing_values[missing_values > 0])

    print("\n" + "="*50 + "\n")  # Separator for readability
# Out:
# Missing Values in DataFrame 1:
# Age            276
# IncomeLevel    285
# dtype: int64
#
# ==================================================
#
# Missing Values in DataFrame 2:
# Amount             283
# ProductCategory    282
# dtype: int64
#
# ==================================================
#
# Missing Values in DataFrame 3:
# Platform     291
# Sentiment    309
# dtype: int64
#
# ==================================================

# %% [markdown]
# Understanding the data types of each column in a dataset is crucial for performing accurate data analysis. The `dtypes` attribute in pandas provides the data type of each column in a DataFrame. This helps verify that the data types are appropriate for the operations intended, such as ensuring numerical columns are treated as floats and date columns are recognized as datetime objects.
#
# The following code loops through each DataFrame (`df1`, `df2`, `df3`) and prints the data types for each column. A separator is added for readability between the outputs of different DataFrames.

# %%
# List of DataFrames
dataframes = [df1, df2, df3]

# Loop through each DataFrame to check data types
for i, df in enumerate(dataframes, 1):
    print(f"Data Types in DataFrame {i}:")

    # Print data types of each column
    print(df.dtypes)

    print("\n" + "="*50 + "\n")  # Separator for readability
# Out:
# Data Types in DataFrame 1:
# CustomerID     object
# Age            object
# Gender         object
# Location       object
# IncomeLevel    object
# SignupDate     object
# dtype: object
#
# ==================================================
#
# Data Types in DataFrame 2:
# CustomerID         object
# TransactionID      object
# TransactionDate    object
# Amount             object
# ProductCategory    object
# PaymentMethod      object
# dtype: object
#
# ==================================================
#
# Data Types in DataFrame 3:
# CustomerID         object
# InteractionID      object
# InteractionDate    object
# Platform           object
# InteractionType    object
# Sentiment          object
# dtype: object
#
# ==================================================

# %%
# List of DataFrames to check and their respective date columns
dfs = [
    (df1, 'SignupDate'),
    (df2, 'TransactionDate'),
    (df3, 'InteractionDate')
]

# Loop over each DataFrame and its respective date column
for i, (df, date_column) in enumerate(dfs, 1):
    # Attempt to convert the date column to datetime, keeping original values intact
    converted_dates = pd.to_datetime(df[date_column], errors='coerce')

    # Find rows where the conversion failed (NaT values) and get the original date formats
    invalid_dates = df.loc[converted_dates.isna(), date_column]

    # Count the number of invalid date formats
    count_invalid = invalid_dates.shape[0]

    # Print the count and the original invalid date formats
    print(f"DataFrame {i} - Column '{date_column}':")
    print(f"Number of invalid date formats: {count_invalid}")

    if count_invalid > 0:
        print("Invalid date formats (original values):")
        print(invalid_dates.values)  # Print the original invalid date values
    else:
        print("No invalid date formats found.")

    print("="*50)  # Separator for better readability
# Out:
# DataFrame 1 - Column 'SignupDate':
# Number of invalid date formats: 98
# Invalid date formats (original values):
# ['30/01/2020' '12/01/2024' '10/01/2022' '14/01/2024' '07/07/2019'
#  '25/11/2020' '10/06/2024' '18/03/2021' '27/06/2023' '24/04/2020'
#  '03/04/2020' '04/02/2024' '22/04/2023' '06/06/2020' '16/02/2023'
#  '11/09/2020' '20/05/2021' '12/11/2019' '26/10/2021' '08/10/2022'
#  '16/03/2020' '22/06/2022' '26/01/2022' '29/07/2021' '25/05/2024'
#  '20/06/2020' '24/04/2022' '01/07/2019' '13/11/2023' '13/05/2021'
#  '06/09/2021' '09/01/2021' '20/10/2022' '09/08/2021' '04/09/2020'
#  '21/11/2019' '25/10/2021' '12/06/2020' '30/03/2020' '12/02/2023'
#  '18/03/2022' '01/10/2021' '15/09/2022' '01/05/2022' '06/08/2019'
#  '13/01/2023' '18/01/2024' '15/11/2019' '08/09/2021' '24/11/2020'
#  '07/01/2021' '03/10/2020' '19/10/2019' '15/05/2020' '22/03/2023'
#  '29/01/2021' '28/11/2020' '03/06/2023' '26/07/2023' '23/10/2023'
#  '16/01/2020' '03/12/2023' '11/10/2020' '18/09/2021' '14/06/2023'
#  '10/03/2020' '12/03/2022' '23/02/2022' '14/05/2022' '08/08/2023'
#  '03/09/2020' '06/10/2023' '04/09/2022' '03/03/2021' '17/12/2023'
#  '19/08/2023' '12/12/2022' '15/08/2022' '12/04/2020' '04/08/2020'
#  '14/11/2020' '06/07/2022' '15/06/2022' '23/01/2022' '17/08/2022'
#  '11/08/2019' '25/12/2023' '26/12/2023' '15/12/2019' '26/07/2021'
#  '01/04/2023' '09/03/2021' '29/06/2020' '10/04/2023' '12/03/2020'
#  '07/11/2019' '18/01/2024' '27/05/2021']
# ==================================================
# DataFrame 2 - Column 'TransactionDate':
# Number of invalid date formats: 98
# Invalid date formats (original values):
# ['01/04/2024' '13/12/2022' '26/10/2022' '25/02/2023' '23/03/2023'
#  '24/05/2023' '16/09/2023' '11/09/2023' '28/10/2022' '12/10/2023'
#  '13/04/2023' '30/07/2022' '29/12/2023' '04/03/2023' '06/07/2022'
#  '12/07/2023' '03/04/2023' '12/06/2024' '18/11/2022' '01/01/2023'
#  '05/06/2023' '13/10/2022' '20/09/2022' '05/07/2022' '19/11/2023'
#  '17/03/2023' '01/08/2022' '30/05/2023' '11/04/2024' '12/01/2023'
#  '06/06/2023' '24/05/2023' '20/10/2022' '28/05/2023' '17/10/2023'
#  '12/06/2024' '26/03/2023' '07/11/2023' '05/05/2024' '02/05/2024'
# Pandas has recognized all columns as object, a generic type for strings or mixed data. However, each column should be converted to the correct data type for improved performance and clarity. Applying these changes will optimize the data and make it more efficient for analysis.

# %%
# Check for rows with invalid dates
invalid_dates = df1[df1['SignupDate'].isna()]
print(invalid_dates)
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age, Gender, Location, IncomeLevel, SignupDate]
# Index: []

# %%
# Changing data types
df1['CustomerID'] = df1['CustomerID'].astype('string')  # Change to string
df1['Gender'] = df1['Gender'].astype('category')  # Change to category
df1['IncomeLevel'] = df1['IncomeLevel'].astype('category')  # Change to category
df1['SignupDate'] = pd.to_datetime(df1['SignupDate'], format='%d/%m/%Y')  # Change to datetime, specifying the correct format

# Convert 'Age' to numeric, replacing invalid values with NaN
df1['Age'] = pd.to_numeric(df1['Age'], errors='coerce')
# NaN (Not a Number) is a special floating-point value that represents missing or invalid data.

# Verify the changes
print(df1.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2ea75e5b9cba> in <cell line: 5>()
#       3 df1['Gender'] = df1['Gender'].astype('category')  # Change to category
#       4 df1['IncomeLevel'] = df1['IncomeLevel'].astype('category')  # Change to category
# ----> 5 df1['SignupDate'] = pd.to_datetime(df1['SignupDate'], format='%d/%m/%Y')  # Change to datetime, specifying the correct format
#       6
#       7 # Convert 'Age' to numeric, replacing invalid values with NaN
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110             result = arg.map(cache_array)
#    1111         else:
# -> 1112             values = convert_listlike(arg._values, format)
#    1113             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487     if format is not None and format != "mixed":
# --> 488         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     489
#     490     result, tz_parsed = objects_to_datetime64ns(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2022-11-17" doesn't match format "%d/%m/%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# This data, represented by `df2`, captures customer transactions across various categories. Each row in the dataset provides detailed information about a specific transaction made by a customer.
#
# The table below shows the **data type**, **description**, **original data type**, and the **target change** for each column, ensuring that the data is properly formatted for analysis:
#
# | Column            | Description                                                         | Original Data Type | Target Data Type   |
# |-------------------|---------------------------------------------------------------------|--------------------|--------------------|
# | **CustomerID**     | Unique identifier for each customer, should remain as a string.     | `object`           | `object` (string)  |
# | **TransactionID**  | Unique identifier for each transaction, should remain as a string.  | `object`           | `object` (string)  |
# | **TransactionDate**| Represents dates, needs to be converted to datetime.               | `object`           | `datetime64`       |
# | **Amount**         | Represents monetary values, needs to be converted to a float.       | `object`           | `float64`          |
# | **ProductCategory**| Categorical data, should remain as a string.                       | `object`           | `object` (string)  |
# | **PaymentMethod**  | Categorical data, should remain as a string.                       | `object`           | `object` (string)  |

# %%
# Convert 'TransactionDate' to datetime
df2['TransactionDate'] = pd.to_datetime(df2['TransactionDate'], errors='coerce')

# Convert 'Amount' to float
df2['Amount'] = pd.to_numeric(df2['Amount'], errors='coerce')

# Print data types of each column in df2 to show change in data type
print(df2.dtypes)

# %% [markdown]
# A. For any numeric value such as Age and Amount, calculate the mean value and populate the missing data with the mean value. The mean value is used instead of leaving these blank.
#
# B. For each record with missing data in some string columns, create a new label called Uncategorized and apply these to the said columns.
#
# 1. Income Level
# 2. Product Category
# 3. Platform
# 4. Sentiment
